# %%
import os
meu_diretorio = "/Users/Bruno/Desktop/Insper/2º SEMESTRE/CIÊNCIA DOS DADOS/PROJETO 1/2013/PNAD DOM2013/DOM2013csv"
os.chdir(meu_diretorio)

import pandas as pd
dados = pd.read_csv('DOM2013.csv')
dados = dados.loc[ : ,["UF","V0224","V2115","V2117","V2121"]]

dados_limpo = dados[pd.notnull(dados.UF) & pd.notnull(dados.V0224) & pd.notnull(dados.V2115) & pd.notnull(dados.V2117) & pd.notnull(dados.V2121)]





dados_limpo.UF = dados_limpo.UF.astype('category')
dados_limpo.V0224 = dados_limpo.V0224.astype('category')
dados_limpo.V2115 = dados_limpo.V2115.astype('category')
dados_limpo.V2117 = dados_limpo.V2117.astype('category')
dados_limpo.V2121 = dados_limpo.V2121.astype('category')



dados_limpo.V0224.cat.categories = (['Sim','Não'])
dados_limpo.V2115.cat.categories = (['Sim','Não'])
dados_limpo.V2117.cat.categories = (['Sim','Não'])
dados_limpo.V2121.cat.categories = (['Sim','Não'])
dados_limpo.UF.cat.categories = (['X','a','b','c','d','e','f','g','h','i','j','k','l','Alagoas','m','n','o','p','q','r','s','t','u','v','w','y','DF'])


dados_limpo.columns = ["UF","FILTRO","COMEU MENOS DO QUE DEVIA PORQUE NÃO TINHA DINHEIRO PARA COMPRAR COMIDA","SENTIU FOME MAS NÃO COMEU PORQUE NÃO TINHA DINHEIRO","FEZ UMA REFEIÇÃO OU MENOS PORQUE NÃO TINHA DINEHRIO"]

dados_limpo[(dados_limpo.UF == 'DF')]
# Out:
# C:\Users\Bruno\Anaconda3\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#         UF FILTRO  \
# 145125  DF    Sim
# 145168  DF    Sim
# 145175  DF    Sim
# 145269  DF    Sim
# 145318  DF    Sim
# 145337  DF    Não
# 145442  DF    Sim
# 145483  DF    Sim
# 145486  DF    Sim
# 145489  DF    Sim
# 145498  DF    Sim
# 145500  DF    Sim
# 145504  DF    Sim
# 145505  DF    Sim
# 145510  DF    Não
# 145513  DF    Sim
# 145530  DF    Sim
# 145532  DF    Sim
# 145534  DF    Sim
# 145537  DF    Sim
# 145540  DF    Sim
# 145545  DF    Sim
# 145546  DF    Sim
# 145548  DF    Sim
# 145551  DF    Sim
# 145554  DF    Sim
# 145558  DF    Não
# 145559  DF    Sim
# 145561  DF    Não
# 145562  DF    Não
# ...

# %%
dados_limpo.FILTRO = dados_limpo.FILTRO.astype('category')
dados_limpo.FILTRO.cat.categories = (['Sim','Não'])
pd.DataFrame(dados_limpo.FILTRO.value_counts())
# Out:
# C:\Users\Bruno\Anaconda3\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#      FILTRO
# Não    8008
# Sim    4266
